# %%
import pandas as pd
import numpy as np
import seaborn as sn
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
df1 = pd.read_csv('/Users/saisatyajonnalagadda/Documents/satya/FOA_Placement_Data_Analysis_Project/Data/Placement_Data_Full_Class.csv')

# %%
df = df1.copy(deep=True)

# %%
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
df.shape
# Out:
# (215, 15)

# %% [markdown]
# ## Data Information
#
# 👉 sl_no: Serial Number<br>
# 👉 gender: Gender- Male='M',Female='F' <br>
# 👉 ssc_p: Secondary Education percentage- 10th Grade <br>
# 👉 ssc_b: Board of Education- Central/ Others <br>
# 👉 hsc_p: Higher Secondary Education percentage- 12th Grade <br>
# 👉 hsc_b: Board of Education- Central/ Others <br>
# 👉 hsc_s: Specialization in Higher Secondary Education <br>
# 👉 degree_p: Degree Percentage <br>
# 👉 degree_t: Under-Graduation(Degree type)- Field of degree education <br>
# 👉 workex: Work Experience <br>
# 👉 etest_p: Employability test percentage ( conducted by the college) <br>
# 👉 specialisation: Post Graduation(MBA)- Specialization <br>
# 👉 mba_p: MBA percentage <br>
# 👉 status: Status of placement- Placed/Not placed <br>
# 👉 salary: Salary offered by corporate to candidates <br>

# %%
df.isna().sum()
# Out:
# sl_no              0
# gender             0
# ssc_p              0
# ssc_b              0
# hsc_p              0
# hsc_b              0
# hsc_s              0
# degree_p           0
# degree_t           0
# workex             0
# etest_p            0
# specialisation     0
# mba_p              0
# status             0
# salary            67
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Check Null and Dtypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   sl_no           215 non-null    int64
#  1   gender          215 non-null    object
#  2   ssc_p           215 non-null    float64
#  3   ssc_b           215 non-null    object
#  4   hsc_p           215 non-null    float64
#  5   hsc_b           215 non-null    object
#  6   hsc_s           215 non-null    object
#  7   degree_p        215 non-null    float64
#  8   degree_t        215 non-null    object
#  9   workex          215 non-null    object
#  10  etest_p         215 non-null    float64
#  11  specialisation  215 non-null    object
#  12  mba_p           215 non-null    float64
#  13  status          215 non-null    object
#  14  salary          148 non-null    float64
# dtypes: float64(6), int64(1), object(8)
# memory usage: 25.3+ KB

# %%
df.nunique()
# Out:
# sl_no             215
# gender              2
# ssc_p             103
# ssc_b               2
# hsc_p              97
# hsc_b               2
# hsc_s               3
# degree_p           89
# degree_t            3
# workex              2
# etest_p           100
# specialisation      2
# mba_p             205
# status              2
# salary             45
# dtype: int64

# %%
df.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %%
print("Categories in 'gender' variable:             ",end=" " )
print(df['gender'].unique())

print("Categories in 'ssc_b' variable:              ",end=" ")
print(df['ssc_b'].unique())

print("Categories in'hsc_b' variable:               ",end=" " )
print(df['hsc_b'].unique())

print("Categories in 'hsc_s' variable:              ",end=" " )
print(df['hsc_s'].unique())

print("Categories in 'degree_t' variable:           ",end=" " )
print(df['degree_t'].unique())

print("Categories in 'workex' variable:             ",end=" " )
print(df['workex'].unique())

print("Categories in 'specialisation' variable:     ",end=" " )
print(df['specialisation'].unique())

print("Categories in 'status' variable:             ",end=" " )
print(df['status'].unique())
# Out:
# Categories in 'gender' variable:              ['M' 'F']
# Categories in 'ssc_b' variable:               ['Others' 'Central']
# Categories in'hsc_b' variable:                ['Others' 'Central']
# Categories in 'hsc_s' variable:               ['Commerce' 'Science' 'Arts']
# Categories in 'degree_t' variable:            ['Sci&Tech' 'Comm&Mgmt' 'Others']
# Categories in 'workex' variable:              ['No' 'Yes']
# Categories in 'specialisation' variable:      ['Mkt&HR' 'Mkt&Fin']
# Categories in 'status' variable:              ['Placed' 'Not Placed']

# %%
# define numerical & categorical columns
numeric_features = [feature for feature in df.columns if df[feature].dtype != 'O']
categorical_features = [feature for feature in df.columns if df[feature].dtype == 'O']

# print columns
print('We have {} numerical features     : {}'.format(len(numeric_features), numeric_features))
print('\nWe have {} categorical features   : {}'.format(len(categorical_features), categorical_features))
# Out:
# We have 7 numerical features     : ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']
#
# We have 8 categorical features   : ['gender', 'ssc_b', 'hsc_b', 'hsc_s', 'degree_t', 'workex', 'specialisation', 'status']

# %% [markdown]
# ## Total placement Stats

# %%
sn.set_style('whitegrid')
sn.countplot(x='status',data=df)
# Out:
# <Axes: xlabel='status', ylabel='count'>

# %%
df.groupby('status').count()
# Out:
#             sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  \
# status
# Not Placed     67      67     67     67     67     67     67        67
# Placed        148     148    148    148    148    148    148       148
#
#             degree_t  workex  etest_p  specialisation  mba_p  salary
# status
# Not Placed        67      67       67              67     67       0
# Placed           148     148      148             148    148     148

# %%
t = 215
p = 148
np = 67
print("Total students:",t)
print("placement percentage:",(148/215)*100)
# Out:
# Total students: 215
# placement percentage: 68.83720930232559

# %% [markdown]
# ## is gender affects placement

# %%
df.groupby('gender').count()
# Out:
#         sl_no  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  workex  \
# gender
# F          76     76     76     76     76     76        76        76      76
# M         139    139    139    139    139    139       139       139     139
#
#         etest_p  specialisation  mba_p  status  salary
# gender
# F            76              76     76      76      48
# M           139             139    139     139     100

# %%
sn.set_style('whitegrid')
sn.countplot(x='gender',data=df)
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
sn.set_style('whitegrid')
sn.countplot(x='status',hue='gender',data=df)
# Out:
# <Axes: xlabel='status', ylabel='count'>

# %%
t = 215
m = 139
m_placed = 100
print("Male Placement Percentage:",m_placed/m*100)
f = 215-139
f_placed = 148-100
print("Female Placement Percentage:",f_placed/f*100)
# Out:
# Male Placement Percentage: 71.94244604316546
# Female Placement Percentage: 63.1578947368421

# %% [markdown]
# ## is SSC_B affects placement

# %%
df.groupby('ssc_b').count()
# Out:
#          sl_no  gender  ssc_p  hsc_p  hsc_b  hsc_s  degree_p  degree_t  \
# ssc_b
# Central    116     116    116    116    116    116       116       116
# Others      99      99     99     99     99     99        99        99
#
#          workex  etest_p  specialisation  mba_p  status  salary
# ssc_b
# Central     116      116             116    116     116      78
# Others       99       99              99     99      99      70

# %%
sn.set_style('whitegrid')
sn.countplot(x='status',hue='ssc_b',data=df)
# Out:
# <Axes: xlabel='status', ylabel='count'>

# %%
t = 215
central = 116
others = 99
c_placed = 78
o_placed = 70
print("SSB-Central-placed",c_placed/central*100)
print("SSB-others-placed",o_placed/others*100)
# Out:
# SSB-Central-placed 67.24137931034483
# SSB-others-placed 70.70707070707071

# %% [markdown]
# ## is hsc_b affects placement

# %%
df.groupby('hsc_b').count()
# Out:
#          sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_s  degree_p  degree_t  \
# hsc_b
# Central     84      84     84     84     84     84        84        84
# Others     131     131    131    131    131    131       131       131
#
#          workex  etest_p  specialisation  mba_p  status  salary
# hsc_b
# Central      84       84              84     84      84      57
# Others      131      131             131    131     131      91

# %%
sn.set_style('whitegrid')
sn.countplot(x='status',hue='hsc_b',data=df)
# Out:
# <Axes: xlabel='status', ylabel='count'>

# %%
t = 215
c_hsc = 84
o_hsc = 131
placed_c = 57
placed_o = 91
print("HSC-Central-placed: ",placed_c/c_hsc*100)
print("HSC-Others-placed: ",placed_o/o_hsc*100)
# Out:
# HSC-Central-placed:  67.85714285714286
# HSC-Others-placed:  69.46564885496184

# %% [markdown]
# ## is HSC-Stream affects placement

# %%
df.groupby('hsc_s').count()
# Out:
#           sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_b  degree_p  degree_t  \
# hsc_s
# Arts         11      11     11     11     11     11        11        11
# Commerce    113     113    113    113    113    113       113       113
# Science      91      91     91     91     91     91        91        91
#
#           workex  etest_p  specialisation  mba_p  status  salary
# hsc_s
# Arts          11       11              11     11      11       6
# Commerce     113      113             113    113     113      79
# Science       91       91              91     91      91      63

# %%
sn.set_style('whitegrid')
sn.countplot(x='status',hue='hsc_s',data=df)
# Out:
# <Axes: xlabel='status', ylabel='count'>

# %%
arts = 11
commerce = 113
science = 91
arts_p = 6
commerce_p = 79
science_p = 63
print("HSC-Stream Arts placed : ",arts_p/arts*100)
print("HSC-Stream commerce placed : ",commerce_p/commerce*100)
print("HSC-Stream Science placed : ",science_p/science*100)
# Out:
# HSC-Stream Arts placed :  54.54545454545454
# HSC-Stream commerce placed :  69.91150442477876
# HSC-Stream Science placed :  69.23076923076923

# %% [markdown]
# ## is Degree type affects placement

# %%
sn.set_style('whitegrid')
sn.countplot(x='degree_t',data=df)
# Out:
# <Axes: xlabel='degree_t', ylabel='count'>

# %%
df.groupby('degree_t').count()
# Out:
#            sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  workex  \
# degree_t
# Comm&Mgmt    145     145    145    145    145    145    145       145     145
# Others        11      11     11     11     11     11     11        11      11
# Sci&Tech      59      59     59     59     59     59     59        59      59
#
#            etest_p  specialisation  mba_p  status  salary
# degree_t
# Comm&Mgmt      145             145    145     145     102
# Others          11              11     11      11       5
# Sci&Tech        59              59     59      59      41

# %%
sn.set_style('whitegrid')
sn.countplot(x='status',hue='degree_t',data=df)
# Out:
# <Axes: xlabel='status', ylabel='count'>

# %%
comm_mgmt = 145
sci_tech = 59
d_others = 11
com_placed = 102
sci_placed = 41
oth_placed = 5
print("Degree type-Com&Mgmt placed: ",com_placed/comm_mgmt*100)
print("Degree type-Sci&Tech placed: ",sci_placed/sci_tech*100)
print("Degree type-Others placed: ",oth_placed/d_others*100)
# Out:
# Degree type-Com&Mgmt placed:  70.34482758620689
# Degree type-Sci&Tech placed:  69.49152542372882
# Degree type-Others placed:  45.45454545454545

# %% [markdown]
# ## is Work Experiance affects placement

# %%
df.groupby('workex').count()
# Out:
#         sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  degree_t  \
# workex
# No        141     141    141    141    141    141    141       141       141
# Yes        74      74     74     74     74     74     74        74        74
#
#         etest_p  specialisation  mba_p  status  salary
# workex
# No          141             141    141     141      84
# Yes          74              74     74      74      64

# %%
sn.set_style('whitegrid')
sn.countplot(x='status',hue='workex',data=df)
# Out:
# <Axes: xlabel='status', ylabel='count'>

# %%
w_yes = 74
w_no = 141
y_placed = 64
n_placed = 84
print("Work-Experiance YES placed: ",y_placed/w_yes*100)
print("Work-Experiance NO placed: ",n_placed/w_no*100)
# Out:
# Work-Experiance YES placed:  86.48648648648648
# Work-Experiance NO placed:  59.57446808510638

# %% [markdown]
# by above chart, we can conclude work experiance affects the placements

# %% [markdown]
# ## is Specialisation affects the Placement

# %%
df.groupby('specialisation').count()
# Out:
#                 sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  \
# specialisation
# Mkt&Fin           120     120    120    120    120    120    120       120
# Mkt&HR             95      95     95     95     95     95     95        95
#
#                 degree_t  workex  etest_p  mba_p  status  salary
# specialisation
# Mkt&Fin              120     120      120    120     120      95
# Mkt&HR                95      95       95     95      95      53

# %%
sn.set_style('whitegrid')
sn.countplot(x='status',hue='specialisation',data=df)
# Out:
# <Axes: xlabel='status', ylabel='count'>

# %%
mkt_fin = 120
mkt_hr = 95
mktfin_p = 95
mkthr_p = 53
print("MKT&HR placed: ",mkthr_p/mkt_hr*100)
print("MKT&FIN placed: ",mktfin_p/mkt_fin*100)
# Out:
# MKT&HR placed:  55.78947368421052
# MKT&FIN placed:  79.16666666666666

# %% [markdown]
# by above chart we can conclude that specialisation is affecting placement

# %%
test = df.groupby(['workex','specialisation'])
test.size()
# Out:
# workex  specialisation
# No      Mkt&Fin           69
#         Mkt&HR            72
# Yes     Mkt&Fin           51
#         Mkt&HR            23
# dtype: int64

# %%
test = df.groupby(['workex','specialisation','status'])
test.size()
# Out:
# workex  specialisation  status
# No      Mkt&Fin         Not Placed    21
#                         Placed        48
#         Mkt&HR          Not Placed    36
#                         Placed        36
# Yes     Mkt&Fin         Not Placed     4
#                         Placed        47
#         Mkt&HR          Not Placed     6
#                         Placed        17
# dtype: int64

# %%
mk_fin_w_yes = 51
mk_fin_w_yes_p = 47
mk_hr_w_yes = 23
mk_hr_w_yes_p = 17
print("MK_FIN and work exp YES placed:",mk_fin_w_yes_p/mk_fin_w_yes*100)
print("MK_HR and work exp YES placed:",mk_hr_w_yes_p/mk_hr_w_yes*100)
# Out:
# MK_FIN and work exp YES placed: 92.15686274509804
# MK_HR and work exp YES placed: 73.91304347826086

# %% [markdown]
# from the above chart we can conclude that students of MK&FIN specialisation with work experiance yes more likely placed with 92.15% <br>
# MK-HR with work exp yes more likely to get placed than MK_HR without work exp

# %%
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0

# %% [markdown]
# ## is MBA percentage affect placement

# %%
total_mba_p = df['mba_p'].sum()
avg = total_mba_p/215
print(avg)
# Out:
# 62.278186046511635

# %%
df['mba_p_above_avg'] = 'yes'
df.loc[(df['mba_p'] > avg), 'mba_p_above_avg'] = 'yes'
df.loc[(df['mba_p'] < avg), 'mba_p_above_avg'] = 'no'
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary  \
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0
#
#   mba_p_above_avg
# 0              no
# 1             yes
# 2              no
# 3              no
# 4              no

# %%
sn.set_style('whitegrid')
sn.countplot(x='status',hue='mba_p_above_avg',data=df)
# Out:
# <Axes: xlabel='status', ylabel='count'>

# %%
df.groupby('mba_p_above_avg').count()
# Out:
#                  sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  \
# mba_p_above_avg
# no                 111     111    111    111    111    111    111       111
# yes                104     104    104    104    104    104    104       104
#
#                  degree_t  workex  etest_p  specialisation  mba_p  status  \
# mba_p_above_avg
# no                    111     111      111             111    111     111
# yes                   104     104      104             104    104     104
#
#                  salary
# mba_p_above_avg
# no                   74
# yes                  74

# %%
mba_p_av_y = 104
mba_p_av_n = 111
mba_p_av_y_placed = 74
mba_p_av_n_placed = 74
print("students who scored above average in MBA_P placed are:",mba_p_av_y_placed/mba_p_av_y*100)
print("students who scored below average in MBA_P placed are:",mba_p_av_n_placed/mba_p_av_n*100)
# Out:
# students who scored above average in MBA_P placed are: 71.15384615384616
# students who scored below average in MBA_P placed are: 66.66666666666666

# %% [markdown]
# ## is ETEST percentage affect placement

# %%
total_etest_p = df['etest_p'].sum()
avg_etest = total_etest_p/215
print(avg_etest)
# Out:
# 72.10055813953488

# %%
df['etest_p_above_avg'] = 'yes'
df.loc[(df['etest_p'] > avg_etest), 'etest_p_above_avg'] = 'yes'
df.loc[(df['etest_p'] < avg_etest), 'etest_p_above_avg'] = 'no'
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary  \
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0
#
#   mba_p_above_avg etest_p_above_avg
# 0              no                no
# 1             yes               yes
# 2              no               yes
# 3              no                no
# 4              no               yes

# %%
sn.set_style('whitegrid')
sn.countplot(x='status',hue='etest_p_above_avg',data=df)
# Out:
# <Axes: xlabel='status', ylabel='count'>

# %%
df.groupby('etest_p_above_avg').count()
# Out:
#                    sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  \
# etest_p_above_avg
# no                   116     116    116    116    116    116    116       116
# yes                   99      99     99     99     99     99     99        99
#
#                    degree_t  workex  etest_p  specialisation  mba_p  status  \
# etest_p_above_avg
# no                      116     116      116             116    116     116
# yes                      99      99       99              99     99      99
#
#                    salary  mba_p_above_avg
# etest_p_above_avg
# no                     75              116
# yes                    73               99

# %%
etest_p_av_y = 99
etest_p_av_n = 116
etest_p_av_y_placed = 73
etest_p_av_n_placed = 75
print("students who scored above average in ETEST_P placed are:",etest_p_av_y_placed/etest_p_av_y*100)
print("students who scored below average in ETEST_P placed are:",etest_p_av_n_placed/etest_p_av_n*100)
# Out:
# students who scored above average in ETEST_P placed are: 73.73737373737373
# students who scored below average in ETEST_P placed are: 64.65517241379311

# %%
test1 = df.groupby(['etest_p_above_avg','mba_p_above_avg'])
test1.size()
# Out:
# etest_p_above_avg  mba_p_above_avg
# no                 no                 68
#                    yes                48
# yes                no                 43
#                    yes                56
# dtype: int64

# %%
test1 = df.groupby(['etest_p_above_avg','mba_p_above_avg','status'])
test1.size()
# Out:
# etest_p_above_avg  mba_p_above_avg  status
# no                 no               Not Placed    21
#                                     Placed        47
#                    yes              Not Placed    20
#                                     Placed        28
# yes                no               Not Placed    16
#                                     Placed        27
#                    yes              Not Placed    10
#                                     Placed        46
# dtype: int64

# %%
print("students who scored above avg both in ETEST_P and MBA_P placed are:",46/56*100)
# Out:
# students who scored above avg both in ETEST_P and MBA_P placed are: 82.14285714285714

# %% [markdown]
# ## is Degree percentage affect placement

# %%
total_degree_p = df['degree_p'].sum()
avg_degree_p = total_degree_p/215
print(avg_degree_p)
# Out:
# 66.37018604651163

# %%
df['degree_p_above_avg'] = 'yes'
df.loc[(df['degree_p'] > avg_degree_p), 'degree_p_above_avg'] = 'yes'
df.loc[(df['degree_p'] < avg_degree_p), 'degree_p_above_avg'] = 'no'
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary  \
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0
#
#   mba_p_above_avg etest_p_above_avg degree_p_above_avg
# 0              no                no                 no
# 1             yes               yes                yes
# 2              no               yes                 no
# 3              no                no                 no
# 4              no               yes                yes

# %%
sn.set_style('whitegrid')
sn.countplot(x='status',hue='degree_p_above_avg',data=df)
# Out:
# <Axes: xlabel='status', ylabel='count'>

# %%
df.groupby('degree_p_above_avg').count()
# Out:
#                     sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  \
# degree_p_above_avg
# no                    119     119    119    119    119    119    119
# yes                    96      96     96     96     96     96     96
#
#                     degree_p  degree_t  workex  etest_p  specialisation  \
# degree_p_above_avg
# no                       119       119     119      119             119
# yes                       96        96      96       96              96
#
#                     mba_p  status  salary  mba_p_above_avg  etest_p_above_avg
# degree_p_above_avg
# no                    119     119      61              119                119
# yes                    96      96      87               96                 96

# %%
degree_p_av_y = 96
degree_p_av_n = 119
degree_p_av_y_placed = 87
degree_p_av_n_placed = 61
print("students who scored above average in DEGREE_P placed are:",degree_p_av_y_placed/degree_p_av_y*100)
print("students who scored below average in DEGREE_P placed are:",degree_p_av_n_placed/degree_p_av_n*100)
# Out:
# students who scored above average in DEGREE_P placed are: 90.625
# students who scored below average in DEGREE_P placed are: 51.26050420168067

# %%
test2 = df.groupby(['etest_p_above_avg','mba_p_above_avg','degree_p_above_avg'])
test2.size()
# Out:
# etest_p_above_avg  mba_p_above_avg  degree_p_above_avg
# no                 no               no                    48
#                                     yes                   20
#                    yes              no                    25
#                                     yes                   23
# yes                no               no                    29
#                                     yes                   14
#                    yes              no                    17
#                                     yes                   39
# dtype: int64

# %%
test2 = df.groupby(['etest_p_above_avg','mba_p_above_avg','degree_p_above_avg','status'])
test2.size()
# Out:
# etest_p_above_avg  mba_p_above_avg  degree_p_above_avg  status
# no                 no               no                  Not Placed    20
#                                                         Placed        28
#                                     yes                 Not Placed     1
#                                                         Placed        19
#                    yes              no                  Not Placed    18
#                                                         Placed         7
#                                     yes                 Not Placed     2
#                                                         Placed        21
# yes                no               no                  Not Placed    13
#                                                         Placed        16
#                                     yes                 Not Placed     3
#                                                         Placed        11
#                    yes              no                  Not Placed     7
#                                                         Placed        10
#                                     yes                 Not Placed     3
#                                                         Placed        36
# dtype: int64

# %%
print("students who scored above avg in ETEST_P, MBA_P and DEGREE_P placed are:",36/39*100)
# Out:
# students who scored above avg in ETEST_P, MBA_P and DEGREE_P placed are: 92.3076923076923

# %% [markdown]
# ## is HSC percentage affect placements

# %%
total_hsc_p = df['hsc_p'].sum()
avg_hsc_p = total_hsc_p/215
print(avg_hsc_p)
# Out:
# 66.33316279069768

# %%
df['hsc_p_above_avg'] = 'yes'
df.loc[(df['hsc_p'] > avg_hsc_p), 'hsc_p_above_avg'] = 'yes'
df.loc[(df['hsc_p'] < avg_hsc_p), 'hsc_p_above_avg'] = 'no'
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary  \
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0
#
#   mba_p_above_avg etest_p_above_avg degree_p_above_avg hsc_p_above_avg
# 0              no                no                 no             yes
# 1             yes               yes                yes             yes
# 2              no               yes                 no             yes
# 3              no                no                 no              no
# 4              no               yes                yes             yes

# %%
sn.set_style('whitegrid')
sn.countplot(x='status',hue='hsc_p_above_avg',data=df)
# Out:
# <Axes: xlabel='status', ylabel='count'>

# %%
df.groupby('hsc_p_above_avg').count()
# Out:
#                  sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  \
# hsc_p_above_avg
# no                 117     117    117    117    117    117    117       117
# yes                 98      98     98     98     98     98     98        98
#
#                  degree_t  workex  etest_p  specialisation  mba_p  status  \
# hsc_p_above_avg
# no                    117     117      117             117    117     117
# yes                    98      98       98              98     98      98
#
#                  salary  mba_p_above_avg  etest_p_above_avg  \
# hsc_p_above_avg
# no                   63              117                117
# yes                  85               98                 98
#
#                  degree_p_above_avg
# hsc_p_above_avg
# no                              117
# yes                              98

# %%
hsc_p_av_y = 98
hsc_p_av_n = 117
hsc_p_av_y_placed = 85
hsc_p_av_n_placed = 63
print("students who scored above average in HSC_P placed are:",hsc_p_av_y_placed/hsc_p_av_y*100)
print("students who scored below average in HSC_P placed are:",hsc_p_av_n_placed/hsc_p_av_n*100)
# Out:
# students who scored above average in HSC_P placed are: 86.73469387755102
# students who scored below average in HSC_P placed are: 53.84615384615385

# %%
test3 = df.groupby(['etest_p_above_avg','mba_p_above_avg','degree_p_above_avg','hsc_p_above_avg'])
test3.size()
# Out:
# etest_p_above_avg  mba_p_above_avg  degree_p_above_avg  hsc_p_above_avg
# no                 no               no                  no                 33
#                                                         yes                15
#                                     yes                 no                 12
#                                                         yes                 8
#                    yes              no                  no                 15
#                                                         yes                10
#                                     yes                 no                 10
#                                                         yes                13
# yes                no               no                  no                 22
#                                                         yes                 7
#                                     yes                 no                  7
#                                                         yes                 7
#                    yes              no                  no                  9
#                                                         yes                 8
#                                     yes                 no                  9
#                                                         yes                30
# dtype: int64

# %%
test3 = df.groupby(['etest_p_above_avg','mba_p_above_avg','degree_p_above_avg','hsc_p_above_avg','status'])
test3.size()
# Out:
# etest_p_above_avg  mba_p_above_avg  degree_p_above_avg  hsc_p_above_avg  status
# no                 no               no                  no               Not Placed    17
#                                                                          Placed        16
#                                                         yes              Not Placed     3
#                                                                          Placed        12
#                                     yes                 no               Not Placed     1
#                                                                          Placed        11
#                                                         yes              Placed         8
#                    yes              no                  no               Not Placed    13
#                                                                          Placed         2
#                                                         yes              Not Placed     5
#                                                                          Placed         5
#                                     yes                 no               Not Placed     2
#                                                                          Placed         8
#                                                         yes              Placed        13
# yes                no               no                  no               Not Placed    12
#                                                                          Placed        10
#                                                         yes              Not Placed     1
#                                                                          Placed         6
#                                     yes                 no               Not Placed     2
#                                                                          Placed         5
#                                                         yes              Not Placed     1
#                                                                          Placed         6
#                    yes              no                  no               Not Placed     6
#                                                                          Placed         3
#                                                         yes              Not Placed     1
#                                                                          Placed         7
#                                     yes                 no               Not Placed     1
#                                                                          Placed         8
#                                                         yes              Not Placed     2
#                                                                          Placed        28
# dtype: int64

# %%
print("students who scored above avg in ETEST_P, MBA_P, DEGREE_P and HSC_P placed are:",28/30*100)
# Out:
# students who scored above avg in ETEST_P, MBA_P, DEGREE_P and HSC_P placed are: 93.33333333333333

# %% [markdown]
# ## is SSC Percentage affects placements

# %%
total_ssc_p = df['ssc_p'].sum()
avg_ssc_p = total_ssc_p/215
print(avg_ssc_p)
# Out:
# 67.30339534883721

# %%
df['ssc_p_above_avg'] = 'yes'
df.loc[(df['ssc_p'] > avg_ssc_p), 'ssc_p_above_avg'] = 'yes'
df.loc[(df['ssc_p'] < avg_ssc_p), 'ssc_p_above_avg'] = 'no'
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary  \
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0
#
#   mba_p_above_avg etest_p_above_avg degree_p_above_avg hsc_p_above_avg  \
# 0              no                no                 no             yes
# 1             yes               yes                yes             yes
# 2              no               yes                 no             yes
# 3              no                no                 no              no
# 4              no               yes                yes             yes
#
#   ssc_p_above_avg
# 0              no
# 1             yes
# 2              no
# 3              no
# 4             yes

# %%
sn.set_style('whitegrid')
sn.countplot(x='status',hue='ssc_p_above_avg',data=df)
# Out:
# <Axes: xlabel='status', ylabel='count'>

# %%
df.groupby('ssc_p_above_avg').count()
# Out:
#                  sl_no  gender  ssc_p  ssc_b  hsc_p  hsc_b  hsc_s  degree_p  \
# ssc_p_above_avg
# no                 113     113    113    113    113    113    113       113
# yes                102     102    102    102    102    102    102       102
#
#                  degree_t  workex  etest_p  specialisation  mba_p  status  \
# ssc_p_above_avg
# no                    113     113      113             113    113     113
# yes                   102     102      102             102    102     102
#
#                  salary  mba_p_above_avg  etest_p_above_avg  \
# ssc_p_above_avg
# no                   54              113                113
# yes                  94              102                102
#
#                  degree_p_above_avg  hsc_p_above_avg
# ssc_p_above_avg
# no                              113              113
# yes                             102              102

# %%
ssc_p_av_y = 102
ssc_p_av_n = 113
ssc_p_av_y_placed = 94
ssc_p_av_n_placed = 54
print("students who scored above average in SSC_P placed are:",ssc_p_av_y_placed/ssc_p_av_y*100)
print("students who scored below average in SSC_P placed are:",ssc_p_av_n_placed/ssc_p_av_n*100)
# Out:
# students who scored above average in SSC_P placed are: 92.15686274509804
# students who scored below average in SSC_P placed are: 47.78761061946903

# %%
test3 = df.groupby(['etest_p_above_avg','mba_p_above_avg','degree_p_above_avg','hsc_p_above_avg','ssc_p_above_avg'])
test3.size()
# Out:
# etest_p_above_avg  mba_p_above_avg  degree_p_above_avg  hsc_p_above_avg  ssc_p_above_avg
# no                 no               no                  no               no                 27
#                                                                          yes                 6
#                                                         yes              no                 11
#                                                                          yes                 4
#                                     yes                 no               no                  5
#                                                                          yes                 7
#                                                         yes              no                  4
#                                                                          yes                 4
#                    yes              no                  no               no                 13
#                                                                          yes                 2
#                                                         yes              no                  6
#                                                                          yes                 4
#                                     yes                 no               no                  2
#                                                                          yes                 8
#                                                         yes              no                  5
#                                                                          yes                 8
# yes                no               no                  no               no                 17
#                                                                          yes                 5
#                                                         yes              no                  3
#                                                                          yes                 4
#                                     yes                 no               no                  3
#                                                                          yes                 4
#                                                         yes              no                  5
#                                                                          yes                 2
#                    yes              no                  no               no                  4
#                                                                          yes                 5
#                                                         yes              no                  3
#                                                                          yes                 5
#                                     yes                 no               no                  2
#                                                                          yes                 7
#                                                         yes              no                  3
#                                                                          yes                27
# dtype: int64

# %%
test3 = df.groupby(['etest_p_above_avg','mba_p_above_avg','degree_p_above_avg','hsc_p_above_avg','ssc_p_above_avg','status'])
test3.size()
# Out:
# etest_p_above_avg  mba_p_above_avg  degree_p_above_avg  hsc_p_above_avg  ssc_p_above_avg  status
# no                 no               no                  no               no               Not Placed    17
#                                                                                           Placed        10
#                                                                          yes              Placed         6
#                                                         yes              no               Not Placed     3
#                                                                                           Placed         8
#                                                                          yes              Placed         4
#                                     yes                 no               no               Not Placed     1
#                                                                                           Placed         4
#                                                                          yes              Placed         7
#                                                         yes              no               Placed         4
#                                                                          yes              Placed         4
#                    yes              no                  no               no               Not Placed    12
#                                                                                           Placed         1
#                                                                          yes              Not Placed     1
#                                                                                           Placed         1
#                                                         yes              no               Not Placed     4
#                                                                                           Placed         2
#                                                                          yes              Not Placed     1
#                                                                                           Placed         3
#                                     yes                 no               no               Placed         2
#                                                                          yes              Not Placed     2
#                                                                                           Placed         6
#                                                         yes              no               Placed         5
#                                                                          yes              Placed         8
# yes                no               no                  no               no               Not Placed    12
#                                                                                           Placed         5
#                                                                          yes              Placed         5
#                                                         yes              no               Not Placed     1
#                                                                                           Placed         2
#                                                                          yes              Placed         4
#                                     yes                 no               no               Not Placed     1
#                                                                                           Placed         2
#                                                                          yes              Not Placed     1
#                                                                                           Placed         3
#                                                         yes              no               Not Placed     1
#                                                                                           Placed         4
#                                                                          yes              Placed         2
#                    yes              no                  no               no               Not Placed     3
#                                                                                           Placed         1
#                                                                          yes              Not Placed     3
#                                                                                           Placed         2
#                                                         yes              no               Not Placed     1
#                                                                                           Placed         2
#                                                                          yes              Placed         5
#                                     yes                 no               no               Not Placed     1
#                                                                                           Placed         1
#                                                                          yes              Placed         7
#                                                         yes              no               Not Placed     2
#                                                                                           Placed         1
#                                                                          yes              Placed        27
# dtype: int64

# %%
print("students who scored above avg in ETEST_P, MBA_P, DEGREE_P HSC_P and SSC_P placed are:",27/27*100)
# Out:
# students who scored above avg in ETEST_P, MBA_P, DEGREE_P HSC_P and SSC_P placed are: 100.0

# %%
df.head()
# Out:
#    sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0      1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1      2      M  79.33  Central  78.33   Others   Science     77.48
# 2      3      M  65.00  Central  68.00  Central      Arts     64.00
# 3      4      M  56.00  Central  52.00  Central   Science     52.00
# 4      5      M  85.80  Central  73.60  Central  Commerce     73.30
#
#     degree_t workex  etest_p specialisation  mba_p      status    salary  \
# 0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0
# 1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0
# 2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0
# 3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN
# 4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0
#
#   mba_p_above_avg etest_p_above_avg degree_p_above_avg hsc_p_above_avg  \
# 0              no                no                 no             yes
# 1             yes               yes                yes             yes
# 2              no               yes                 no             yes
# 3              no                no                 no              no
# 4              no               yes                yes             yes
#
#   ssc_p_above_avg
# 0              no
# 1             yes
# 2              no
# 3              no
# 4             yes

# %%
df.groupby('salary').max()
# Out:
#           sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# salary
# 200000.0    136      M  82.00   Others  90.00   Others   Science     83.00
# 204000.0    214      M  74.00   Others  66.00   Others  Commerce     58.00
# 210000.0    205      F  84.00   Others  75.00   Others   Science     75.50
# 216000.0    210      M  74.00   Others  72.00   Others   Science     69.00
# 218000.0     74      M  77.00  Central  87.00   Others  Commerce     71.72
# 220000.0    177      M  77.00   Others  73.00   Others   Science     65.00
# 225000.0    138      M  67.00   Others  63.00  Central  Commerce     72.00
# 230000.0     93      F  66.50   Others  70.40  Central   Science     71.93
# 231000.0      9      M  73.00  Central  79.00  Central  Commerce     72.00
# 233000.0    147      M  62.00  Central  63.00   Others   Science     66.00
# 236000.0    123      M  66.50   Others  67.00   Others      Arts     70.00
# 240000.0    203      M  86.50   Others  86.00   Others   Science     84.00
# 250000.0    206      M  82.00   Others  92.00   Others   Science     78.30
# 252000.0    186      M  88.00  Central  72.00  Central   Science     78.00
# 255000.0    157      M  84.20  Central  69.40  Central   Science     65.00
# 260000.0    204      M  87.00   Others  70.00   Others   Science     91.00
# 264000.0    192      M  67.00   Others  61.00  Central   Science     72.00
# 265000.0    200      M  69.00   Others  71.50   Others   Science     72.11
# 268000.0     59      M  74.00  Central  62.00   Others   Science     68.00
# 270000.0    193      M  84.00   Others  91.00   Others   Science     75.00
# 275000.0    212      M  83.00   Others  78.50   Others   Science     72.00
# 276000.0    184      M  76.00  Central  80.00  Central   Science     78.00
# 278000.0     33      F  61.00  Central  81.00  Central  Commerce     66.40
# 280000.0    188      M  78.50   Others  79.00   Others   Science     67.00
# 285000.0    163      M  74.20  Central  87.60   Others  Commerce     77.25
# 287000.0     41      F  78.00  Central  77.00   Others  Commerce     80.00
# 290000.0    172      M  80.00   Others  80.00   Others  Commerce     72.00
# 295000.0    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 300000.0    208      M  87.00   Others  90.00   Others   Science     82.00
# 320000.0     38      F  79.00  Central  76.00  Central   Science     65.60
# 336000.0     75      M  56.60  Central  64.80  Central  Commerce     70.20
# 340000.0    154      M  49.00   Others  59.00   Others   Science     65.00
# 350000.0    179      M  84.00   Others  76.50   Others   Science     73.00
# 360000.0    132      M  82.00   Others  97.70   Others   Science     78.86
# 380000.0    102      M  63.00  Central  72.00  Central  Commerce     68.00
# 393000.0     22      F  79.00   Others  76.00   Others  Commerce     85.00
# 400000.0    211      M  89.40   Others  89.83   Others   Science     77.72
# 411000.0     40      M  81.00   Others  68.00   Others   Science     64.00
# 420000.0     96      M  73.00  Central  78.00   Others  Commerce     65.00
# 425000.0      5      M  85.80  Central  73.60  Central  Commerce     73.30
# 450000.0     54      M  80.00   Others  70.00   Others   Science     72.00
# 500000.0    175      M  73.24   Others  80.00   Others   Science     65.00
# 650000.0    178      F  73.00  Central  97.00   Others  Commerce     79.00
# 690000.0    151      M  71.00  Central  58.66  Central   Science     58.00
# 940000.0    120      M  60.80  Central  68.40  Central  Commerce     64.60
#
#            degree_t workex  etest_p specialisation  mba_p  status  \
# salary
# 200000.0   Sci&Tech    Yes    89.00         Mkt&HR  73.52  Placed
# 204000.0  Comm&Mgmt    Yes    78.00         Mkt&HR  60.23  Placed
# 210000.0   Sci&Tech    Yes    80.00         Mkt&HR  68.20  Placed
# 216000.0  Comm&Mgmt     No    89.00         Mkt&HR  65.56  Placed
# 218000.0  Comm&Mgmt     No    86.00        Mkt&Fin  68.63  Placed
# 220000.0  Comm&Mgmt    Yes    71.00         Mkt&HR  57.90  Placed
# 225000.0  Comm&Mgmt     No    56.00         Mkt&HR  60.41  Placed
# 230000.0  Comm&Mgmt     No    72.00        Mkt&Fin  64.27  Placed
# 231000.0  Comm&Mgmt     No    91.34        Mkt&Fin  61.29  Placed
# 233000.0  Comm&Mgmt     No    85.00         Mkt&HR  55.14  Placed
# 236000.0  Comm&Mgmt    Yes    80.40        Mkt&Fin  77.89  Placed
# 240000.0   Sci&Tech    Yes    98.00         Mkt&HR  68.53  Placed
# 250000.0   Sci&Tech    Yes    96.00         Mkt&HR  71.77  Placed
# 252000.0   Sci&Tech    Yes    82.00         Mkt&HR  71.43  Placed
# 255000.0   Sci&Tech    Yes    80.00         Mkt&HR  52.72  Placed
# 260000.0   Sci&Tech    Yes    88.00         Mkt&HR  72.78  Placed
# 264000.0  Comm&Mgmt     No    72.00        Mkt&Fin  61.01  Placed
# 265000.0   Sci&Tech    Yes    73.00         Mkt&HR  57.69  Placed
# 268000.0  Comm&Mgmt     No    74.00        Mkt&Fin  57.99  Placed
# 270000.0   Sci&Tech    Yes    93.40         Mkt&HR  59.42  Placed
# 275000.0   Sci&Tech    Yes    84.00         Mkt&HR  68.07  Placed
# 276000.0   Sci&Tech    Yes    97.00         Mkt&HR  70.48  Placed
# 278000.0  Comm&Mgmt     No    50.89         Mkt&HR  62.21  Placed
# 280000.0   Sci&Tech    Yes    95.00        Mkt&Fin  64.86  Placed
# 285000.0  Comm&Mgmt    Yes    75.20        Mkt&Fin  66.06  Placed
# 287000.0  Comm&Mgmt     No    60.00        Mkt&Fin  66.72  Placed
# 290000.0  Comm&Mgmt    Yes    63.79        Mkt&Fin  66.04  Placed
# 295000.0  Comm&Mgmt    Yes    59.00        Mkt&Fin  69.72  Placed
# 300000.0   Sci&Tech    Yes    96.00         Mkt&HR  72.29  Placed
# 320000.0   Sci&Tech     No    58.00         Mkt&HR  55.47  Placed
# 336000.0  Comm&Mgmt     No    84.27        Mkt&Fin  67.20  Placed
# 340000.0   Sci&Tech    Yes    86.00        Mkt&Fin  62.48  Placed
# 350000.0   Sci&Tech    Yes    75.00         Mkt&HR  73.33  Placed
# 360000.0   Sci&Tech    Yes    97.40         Mkt&HR  74.01  Placed
# 380000.0  Comm&Mgmt     No    78.00         Mkt&HR  60.44  Placed
# 393000.0  Comm&Mgmt     No    95.00        Mkt&Fin  69.06  Placed
# 400000.0   Sci&Tech    Yes    91.00         Mkt&HR  76.26  Placed
# 411000.0   Sci&Tech     No    93.00        Mkt&Fin  62.56  Placed
# 420000.0  Comm&Mgmt    Yes    95.46        Mkt&Fin  62.16  Placed
# 425000.0  Comm&Mgmt     No    96.80        Mkt&Fin  55.50  Placed
# 450000.0   Sci&Tech     No    87.00         Mkt&HR  71.04  Placed
# 500000.0   Sci&Tech    Yes    75.00        Mkt&Fin  66.46  Placed
# 650000.0  Comm&Mgmt    Yes    89.00        Mkt&Fin  70.81  Placed
# 690000.0   Sci&Tech    Yes    56.00        Mkt&Fin  61.30  Placed
# 940000.0  Comm&Mgmt    Yes    82.66        Mkt&Fin  64.34  Placed
#
#          mba_p_above_avg etest_p_above_avg degree_p_above_avg hsc_p_above_avg  \
# salary
# 200000.0             yes               yes                yes             yes
# 204000.0              no               yes                 no              no
# 210000.0             yes               yes                yes             yes
# 216000.0             yes               yes                yes             yes
# 218000.0             yes               yes                yes             yes
# 220000.0              no                no                 no             yes
# 225000.0              no                no                yes              no
# 230000.0             yes                no                yes             yes
# 231000.0              no               yes                yes             yes
# 233000.0              no               yes                 no              no
# 236000.0             yes               yes                yes             yes
# 240000.0             yes               yes                yes             yes
# 250000.0             yes               yes                yes             yes
# 252000.0             yes               yes                yes             yes
# 255000.0              no               yes                 no             yes
# 260000.0             yes               yes                yes             yes
# 264000.0              no                no                yes              no
# 265000.0              no               yes                yes             yes
# 268000.0              no               yes                yes              no
# 270000.0              no               yes                yes             yes
# 275000.0             yes               yes                yes             yes
# 276000.0             yes               yes                yes             yes
# 278000.0              no                no                yes             yes
# 280000.0             yes               yes                yes             yes
# 285000.0             yes               yes                yes             yes
# 287000.0             yes                no                yes             yes
# 290000.0             yes                no                yes             yes
# 295000.0             yes                no                yes             yes
# 300000.0             yes               yes                yes             yes
# 320000.0              no                no                 no             yes
# 336000.0             yes               yes                yes              no
# 340000.0             yes               yes                 no              no
# 350000.0             yes               yes                yes             yes
# 360000.0             yes               yes                yes             yes
# 380000.0              no               yes                yes             yes
# 393000.0             yes               yes                yes             yes
# 400000.0             yes               yes                yes             yes
# 411000.0             yes               yes                 no             yes
# 420000.0              no               yes                 no             yes
# 425000.0              no               yes                yes             yes
# 450000.0             yes               yes                yes             yes
# 500000.0             yes               yes                 no             yes
# 650000.0             yes               yes                yes             yes
# 690000.0              no                no                 no              no
# 940000.0             yes               yes                 no             yes
#
#          ssc_p_above_avg
# salary
# 200000.0             yes
# 204000.0             yes
# 210000.0             yes
# 216000.0             yes
# 218000.0             yes
# 220000.0             yes
# 225000.0              no
# 230000.0              no
# 231000.0             yes
# 233000.0              no
# 236000.0              no
# 240000.0             yes
# 250000.0             yes
# 252000.0             yes
# 255000.0             yes
# 260000.0             yes
# 264000.0              no
# 265000.0             yes
# 268000.0             yes
# 270000.0             yes
# 275000.0             yes
# 276000.0             yes
# 278000.0              no
# 280000.0             yes
# 285000.0             yes
# 287000.0             yes
# 290000.0             yes
# 295000.0              no
# 300000.0             yes
# 320000.0             yes
# 336000.0              no
# 340000.0              no
# 350000.0             yes
# 360000.0             yes
# 380000.0              no
# 393000.0             yes
# 400000.0             yes
# 411000.0             yes
# 420000.0             yes
# 425000.0             yes
# 450000.0             yes
# 500000.0             yes
# 650000.0             yes
# 690000.0             yes
# 940000.0              no

# %% [markdown]
# Student who got the highest placement salary of 940000 scored below avg marks in DEGREE_P and SSC_P

# %%
df['salary'].describe(include="all")
# Out:
# count       148.000000
# mean     288655.405405
# std       93457.452420
# min      200000.000000
# 25%      240000.000000
# 50%      265000.000000
# 75%      300000.000000
# max      940000.000000
# Name: salary, dtype: float64

# %%
sn.pairplot(df)
